# %%
import tensorflow as tf
import tensorflow
import keras
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense
import csv

# %%
#data_train = pd.read_csv("data.csv")
#data_train.head()

# %%
#x_train = data_train.copy()
#y_train = x_train.pop("first")
#day = list(zip(data_train['day'],data_train['month'],data_train['year']))

# %%
#x_train = np.array(x_train)
##x_train

# %%
def predictLotto(d, m, y, data1, data2):
    # Create a Sequential model
    train_model = Sequential([Dense(units=1, input_shape=(3,), activation=None)])
    normalize = layers.Normalization()
    normalize.adapt(X)
    # Compile the model
    train_model.compile(optimizer='adam', loss='mean_squared_error')
    
    # Train the model
    train_model.fit(data1, data2, epochs=roun,batch_size=256)  # Assuming data1 contains input features and data2 contains target labels
    
    # Make predictions
    predict = train_model.predict(np.array([[d, m, y]]))
    
    return predict[0]

# Load data from CSV file
data = pd.read_csv("data.csv")

# Extract input features (X) and target labels (y) from the data
X = data[['day', 'month', 'year']].values  # Replace 'feature1', 'feature2', 'feature3' with your actual feature column names
y = data['first'].values  # Replace 'target' with your actual target column name

# Example usage
iD = int(input("Day: "))
iM = int(input("Month: "))
iY = int(input("Year: "))
roun  = int(input("round train do you want"))
print("\nFirst: %06d" % predictLotto(iD, iM, iY, X, y))
# Out:
# Day: 16
# Month: 4
# Year: 2024
# round train do you want1000
# Epoch 1/1000
# 1/1 [==============================] - 0s 184ms/step - loss: 311196188672.0000
# Epoch 2/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 311193763840.0000
# Epoch 3/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 311191339008.0000
# Epoch 4/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 311188881408.0000
# Epoch 5/1000
# 1/1 [==============================] - 0s 4ms/step - loss: 311186391040.0000
# Epoch 6/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 311183900672.0000
# Epoch 7/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 311181475840.0000
# Epoch 8/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 311179018240.0000
# Epoch 9/1000
# 1/1 [==============================] - 0s 3ms/step - loss: 311176560640.0000
# Epoch 10/1000
# ...
